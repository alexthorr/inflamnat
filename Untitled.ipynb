# %%
import pandas as pd

# %%
# Data and plots management
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Chemoinformatic
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import PandasTools
from rdkit.Chem import Descriptors
PandasTools.RenderImagesInAllDataFrames(images=True) # Visualize molecules
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 7
#       5 # Chemoinformatic
#       6 from rdkit import Chem
# ----> 7 from rdkit.Chem import AllChem
#       8 from rdkit.Chem import PandasTools
#       9 from rdkit.Chem import Descriptors
#
# ImportError: cannot import name 'AllChem' from 'rdkit.Chem' (unknown location)

# %%
df=pd.read_excel('top5_np_classifier_class.xlsx', sheet_name='

# %%
# Test basic RDKit functionality
try:
    from rdkit import Chem
    print(f"RDKit version: {Chem.rdBase.rdkitVersion}")
    print("Basic Chem module imported successfully")
    
    # Test if we can create a molecule
    mol = Chem.MolFromSmiles('CCO')
    if mol:
        print("✓ Can create molecules")
    else:
        print("✗ Cannot create molecules")
        
except ImportError as e:
    print(f"Import error: {e}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 4
#       2 try:
#       3     from rdkit import Chem
# ----> 4     print(f"RDKit version: {Chem.rdBase.rdkitVersion}")
#       5     print("Basic Chem module imported successfully")
#       7     # Test if we can create a molecule
#
# AttributeError: module 'rdkit.Chem' has no attribute 'rdBase'
